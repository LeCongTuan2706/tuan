# %%
#dinh nghia tac dung cua ham, bool la dạng hàm de xet dung sai
def check_perfectnumber(x: int) -> bool:
    tong_uoc = 0
    for i in range(1, x//2 + 1):
        if x % i == 0:
            tong_uoc += 1
    return tong_uoc == x
n = int(input())
for x in range (2, n + 1):
    if check_perfectnumber(i):
        print(i, end=' ')

# %%
def tongcacchusochan(x: int) -> int:
    tong = 0
    while x > 0:
        if (x % 10) % 2 == 0:
            tong += x
        x //= 10
    return tong
number = int(input())
print(tongcacchusochan(number))

# %%
string = input()
tongDigit = 0
for ch in string:
    if ch.isdigit():
        tongDigit += int(ch)
print(tongDigit)
# Out:
# 12

# %%
d = {'a': 1, 'b': 2, 'a': 3}
print(d['a'])
# Out:
# 3

# %%
a = [1, 2, 3]
b = a
b.append(4)
print(a)
# Out:
# [1, 2, 3, 4]
