# %%
from debugpy.launcher import channel

x=(1,2)
y=(10,2.5)
x(0)= 1
x(1)=2
y(0)=10
y(1)=2,6
S=x(1) * y(1) + x(0) * y(0)
print("tong tien:S")
# Out:
#   Cell In[6], line 3
#     x(0)= 1
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?

# %%
a = int(input ("nhap diem: "))
if a>=90 and a<=100:
    print ("A")
elif a>=70:
    print ("B")
else:
    print ("fail")
# Out:
# A

# %%
a = [1, 2, 3, 4, 5, 6]
for i in a:
    ìf i % 2 == 0:
        print (i, "la so chan")
# Out:
#   Cell In[45], line 3
#     ìf i % 2 == 0:
#        ^
# SyntaxError: invalid syntax

# %%
def avg(num):
    if len(num) == 0:
        return 0
    else:
        return sum(num)/len(num)
num = list(range (11))
trungbinh = avg(num)
print (trungbinh)
# Out:
# 5.0

# %%
a = [int(item) for item in input().split()]
def avg(a):
    if len(a) == 0:
        return 0
    else:
        return sum(a)/len(a)
trungbinh = avg(a)
print (trungbinh)
# Out:
# 4.5

# %%
a = int(input("nhap 1 so bat ki: "))
if a & (a - 1) == 0:
    print("la luy thua cua 2")
else:
    print("khong phai luy thua cua 2")
# Out:
# khong phai luy thua cua 2

# %%
m = float(input("nhap 1 so bat ki: "))
n = float(input("nhap 1 so bat ki: "))
k = m // n
print (k)
# Out:
# 0.0

# %%
n = int(input("nhap 1 so bat ki: "))
if n > 0:
    if n % 2 == 0:
        print ("even")
    else:
        print ("odd")
else:
    print ("vui long nhap so nguyen duong")
# Out:
# even

# %%
a = int(input("nhap 1 so bat ki: "))
b = int(input("nhap 1 so bat ki: "))
if a*b>0:
    print("yes")
else:
    print("no")
# Out:
# yes

# %%
a = int(input("nhap 1 so bat ki: "))
b = int(input("nhap 1 so bat ki: "))
c = int(input("nhap 1 so bat ki: "))
d = int(input("nhap 1 so bat ki: "))
songuyenlonnhat = max(a,b,c,d)
print(songuyenlonnhat)
# Out:
# 7

# %%
a = int(input("nhap do dai canh: "))
b = int(input("nhap do dai canh: "))
c = int(input("nhap do dai canh: "))
if a>0 and b>0 and c>0:
    if (a+b>c) and (a+c>b) and (b+c>a):
        print("true")
    else:
        print("false")
else:
    print("nhap so nguyen duong")
# Out:
# true

# %%
a = input("nhap chuoi ki tu bat ki: ")
b = input("nhap chuoi ki tu bat ki: ")
if len(a)>len(b):
    print("true")
else:
    print("false")
# Out:
# false

# %%
a = int(input("nhap do dai canh: "))
b = int(input("nhap do dai canh: "))
c = int(input("nhap do dai canh: "))
if a>0 and b>0 and c>0:
    if (a+b>c) and (a+c>b) and (b+c>a) and (c+b>a) and a!=b!=c:
        print("la tam giac thuong")
    elif a==b and b!=c or a==c and c!=b or b==c and c!=a:
        print("la tam giac can")
    elif a==b==c:
        print("la tam giac deu")
    else:
        print("false")
else:
    print("nhap so nguyen duong")
# Out:
# la tam giac can

# %%
x = int(input("nhap so giay bat ki: "))
gio = x//3600
phut = (x%3600)//60
giay = (x%3600)%60
print (gio, "gio", phut, "phut", giay, "giay")
# Out:
# 56 gio 24 phut 5 giay
