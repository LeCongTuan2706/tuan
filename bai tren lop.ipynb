# %%
x=(1,2)
y=(10,2.5)
x(0)= 1
x(1)=2
y(0)=10
y(1)=2,6
S=x(1) * y(1) + x(0) * y(0)
print("tong tien:S")
# Out:
#   Cell In[6], line 3
#     x(0)= 1
#     ^
# SyntaxError: cannot assign to function call here. Maybe you meant '==' instead of '='?
