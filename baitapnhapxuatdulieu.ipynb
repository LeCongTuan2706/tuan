# %%
from sys import maxunicode

print("Hello world")
# Out:
# Hello world

# %%
input("lecongtuan")
# Out:
# 'xinchao\n'

# %%
# Nhập hai số nguyên a và b
a = int(input("Nhập a: "))
b = int(input("Nhập b: "))

# Tính thương và phần dư khi chia a cho b
thuong = a // b     # phép chia lấy phần nguyên
phan_du = a % b     # phép chia lấy phần dư

# In kết quả ra màn hình
print("Thương:", thuong)
print("Phần dư:", phan_du)
# Out:
# Thương: 0
# Phần dư: 5

# %%
a1 = int(input("Nhập điểm 1: "))
b1 = int(input("Nhập điểm 2: "))
c1 = int(input("Nhập điểm 3: "))
a2 = int(input("Nhập điểm 4: "))
b2 = int(input("Nhập điểm 5: "))
c2 = int(input("Nhập điểm 6: "))

TB = ((a1 + b1 + c1) + (a2 + b2 + c2) * 2) / 10


print("Điểm trung bình:", round(TB, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 5
#       3 c1 = int(input("Nhập điểm 3: "))
#       4 a2 = int(input("Nhập điểm 4: "))
# ----> 5 b2 = int(input("Nhập điểm 5: "))
#       6 c2 = int(input("Nhập điểm 6: "))
#       8 TB = ((a1 + b1 + c1) + (a2 + b2 + c2) * 2) / 10
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a, b = input().split()
a = int(a)
b = int(b)
S = a**b
print (S)
# Out:
# 823543

# %%
kituthuong = input()
if len(kituthuong) != 1:
    print("nhap sai ki tu")
else:
    maxunicode = ord(kituthuong)
    print ("ma unicode la:", maxunicode)
# Out:
# ma unicode la: 107
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 7
#       5 maxunicode = ord(kituthuong)
#       6 print ("ma unicode la:", maxunicode)
# ----> 7 kituhoa = kituthuong, upper()
#
# NameError: name 'upper' is not defined

# %%
print ("*")
print ("***")
print ("*****")
# Out:
# *
# ***
# *****

# %%
print ("### ##  ### ###")
print (" #  # #  #   #")
print (" #  #  # #   #")
print (" #  #  # #   #")
print (" #  # #  #   #")
# Out:
# ### ##  ### ###
#  #  # #  #   #
#  #  #  # #   #
#  #  #  # #   #
#  #  # #  #

# %%
A = ((13**2) * 3) + 5
B = 13**2 * 3 + 5


print(A)
print(B)
# Out:
# 512
# 512

# %%
C = float(input())
F = 9/5 * C + 32
print(f"{F:.2f}")

# %%
ky_tu_thuong = input()


print(ord(ky_tu_thuong))


print(ky_tu_thuong.upper())
# Out:
# 97
# A

# %%
x = float(input())
tong_tien = (x + 10) * 1.40
print(f"{tong_tien:.2f}")
# Out:
# 16.80

# %%
n = int(input())
so_mieng_dan = 6 * (n ** 2)
print(so_mieng_dan)
# Out:
# 54

# %%
a, b = map(int, input().split())
hang_don_vi = (a * b) % 10
print(hang_don_vi)
# Out:
# 8

# %%
def blast_off_loop(n):
    for i in range(n, 0 , -1):
        print(i)
    print('blast off!')
n = int(input())
blast_off_loop(n)
# Out:
# 3
# 2
# 1
# blast off!
